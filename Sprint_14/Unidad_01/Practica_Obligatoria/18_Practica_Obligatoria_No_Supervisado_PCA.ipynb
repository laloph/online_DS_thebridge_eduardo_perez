# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: **No Supervisado: PCA**

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en aplicar PCA a un dataset de imágenes con diferentes objetivos y compromisos. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### El problema de negocio
#
# El Caesar Palace de las Vegas está planificando la instalación de mil quininetas microcámaras en los accesos a sus instalaciones para las próximas sesiones del "Poker World Championship". Estas microcámaras tienen la peculiaridad de que son capaces de tomar fotos encuadradas de las caras y la desventaja de que no tienen un gran ancho de banda de comunicación. (Las había de más ancho y de mayor precio...). NOTA: El ancho de banda limita el tamaño de las imágenes que pueden enviar las microcámaras).
#
# El objetivo de las microcámaras es el de detectar personas "non-gratas" en tiempo real, pudiendo posprocesar las imágenes para poder detectar si han accedido a las instalaciones personas que estuvieran perseguidas por la ley, en los bancos de datos de los casinos identificadas como "peligrosas" (no se sabe si para el resto de personas o para los beneficios de los casinos) y en las listas de no admisión de jugadores adictos. Por eso no necesitan procesar los datos en tiempo real, pero sí enviarlos a un repositorio central.
#
# ¿Cuál es su problema? O bien comprimen las imágenes y las procesan comprimidas en cada microcámara (pueden comprimir muy rápido pero no tienen cpu para procesarlas sin comprimir) o bien las comprimen y las mandan a un servidor central muy rápido (por eso ti) donde se descomprimirían y se analizarían. Analizar quiere decir en este contexto, pasarles un modelo de clasificación que determine si la persona de la imagen es una de las listas prohibidas (o sea que clasifique la imágen).
#
# Nos han enviado un dataset y con él debemos estudiar cuál de las dos soluciones es más interesante y dar recomendaciones al respecto. Vamos a ello.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd

import seaborn as sns

from sklearn.decomposition import PCA

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import classification_report, recall_score

from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# ### #1 MODELO DE BASE

# %% [markdown]
# **Objetivo:** Construir un modelo baseline de clasficación de imágenes que las trate sin comprimir (es decir usando todos sus píxeles).

# %% [markdown]
# Para conseguir el objetivo, primero descarga el dataset de las caras de Olivetti que ya has utilizado anteriormente, empleando las funciones de sklearn necesarias. Luego, construye un clasificador con el modelo que consideres más apropiado y todas las features del dataset. Eso sí, recuerda hacer lo siguiente:
#
# 1. Construir un data frame con los datos
# 2. Hacer un split en train y test con al menos 80 instancias en el test y estratificado según el target. Este split se ha de mantener en el resto de la práctica
# 3. Hacer un quick miniEDA o justificar el no hacerlo.
# 4. Medir la recall media (“balanced_accuracy”) sobre cross validation con 5 folds y sobre el conjunto de test y guarda ambas para usarlas como baseline en las siguientes partes

# %%
from sklearn.datasets import fetch_olivetti_faces

olivetti = fetch_olivetti_faces()

df = pd.DataFrame(olivetti.data, columns=[f"pixel_{i}" for i in range(olivetti.data.shape[1])])
df["face_id"] = olivetti.target
target = "face_id"

df
# Out:
#       pixel_0   pixel_1   pixel_2   pixel_3   pixel_4   pixel_5   pixel_6  \
# 0    0.309917  0.367769  0.417355  0.442149  0.528926  0.607438  0.657025
# 1    0.454545  0.471074  0.512397  0.557851  0.595041  0.640496  0.681818
# 2    0.318182  0.400826  0.491736  0.528926  0.586777  0.657025  0.681818
# 3    0.198347  0.194215  0.194215  0.194215  0.190083  0.190083  0.243802
# 4    0.500000  0.545455  0.582645  0.623967  0.648760  0.690083  0.694215
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.400826  0.495868  0.570248  0.632231  0.648760  0.640496  0.661157
# 396  0.367769  0.367769  0.351240  0.301653  0.247934  0.247934  0.367769
# 397  0.500000  0.533058  0.607438  0.628099  0.657025  0.632231  0.657025
# 398  0.214876  0.219008  0.219008  0.223140  0.210744  0.202479  0.276859
# 399  0.516529  0.462810  0.280992  0.252066  0.247934  0.367769  0.574380
#
#       pixel_7   pixel_8   pixel_9  ...  pixel_4087  pixel_4088  pixel_4089  \
# 0    0.677686  0.690083  0.685950  ...    0.669421    0.652893    0.661157
# 1    0.702479  0.710744  0.702479  ...    0.157025    0.136364    0.148760
# 2    0.685950  0.702479  0.698347  ...    0.132231    0.181818    0.136364
# 3    0.404959  0.483471  0.516529  ...    0.636364    0.657025    0.685950
# 4    0.714876  0.723140  0.731405  ...    0.161157    0.177686    0.173554
# ..        ...       ...       ...  ...         ...         ...         ...
# 395  0.636364  0.665289  0.698347  ...    0.396694    0.264463    0.099174
# 396  0.512397  0.574380  0.628099  ...    0.334711    0.289256    0.285124
# 397  0.669421  0.673554  0.702479  ...    0.148760    0.152893    0.161157
# 398  0.400826  0.487603  0.549587  ...    0.392562    0.367769    0.409091
# 399  0.615702  0.661157  0.615702  ...    0.264463    0.293388    0.301653
#
#      pixel_4090  pixel_4091  pixel_4092  pixel_4093  pixel_4094
columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Columns: 4097 entries, pixel_0 to face_id
# dtypes: float32(4096), int64(1)
# memory usage: 6.3 MB

# %%
train_set, test_set = train_test_split(df, test_size= 80, stratify = df[target], random_state= 42)

# %%
X_train = train_set.drop(target, axis = 1)
y_train = train_set[target]

X_test = test_set.drop(target, axis = 1)
y_test = test_set[target]

# %%
rf_clf_importancia = RandomForestClassifier(random_state = 42)
rf_clf_importancia.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_clf_importancia.feature_importances_.reshape(64,64)
# Out:
# array([[4.23388826e-04, 1.84802041e-04, 3.48229285e-04, ...,
#         3.23841556e-04, 0.00000000e+00, 3.10258564e-04],
#        [0.00000000e+00, 9.05504932e-05, 1.71413759e-04, ...,
#         4.81939189e-04, 2.63737065e-04, 6.26881724e-05],
#        [1.89590909e-04, 1.18041475e-04, 3.39419165e-04, ...,
#         5.71667191e-05, 1.51590843e-04, 4.03712788e-04],
#        ...,
#        [3.21252886e-05, 1.20105629e-04, 2.37225869e-04, ...,
#         1.12546978e-04, 0.00000000e+00, 4.62653770e-04],
#        [3.65692557e-04, 5.89638444e-05, 1.10208018e-04, ...,
#         7.88878277e-05, 7.20899297e-04, 2.72045994e-04],
#        [6.21262872e-04, 8.44798455e-05, 6.35645552e-04, ...,
#         0.00000000e+00, 3.32351953e-04, 8.55331040e-04]])

# %%
imagen_importancia = rf_clf_importancia.feature_importances_.reshape(64,64)
plt.imshow(imagen_importancia)
plt.colorbar()

# %%
pd.Series(rf_clf_importancia.feature_importances_).describe()
# Out:
# count    4096.000000
# mean        0.000244
# std         0.000280
# min         0.000000
# 25%         0.000032
# 50%         0.000172
# 75%         0.000353
# max         0.002314
# dtype: float64

# %%
df_describe = X_train.describe().T
df_describe
# Out:
#             count      mean       std       min       25%       50%       75%  \
# pixel_0     320.0  0.402415  0.181016  0.086777  0.246901  0.400826  0.530992
# pixel_1     320.0  0.435873  0.189294  0.066116  0.267562  0.460744  0.574380
# pixel_2     320.0  0.478022  0.194538  0.090909  0.314050  0.512397  0.632231
# pixel_3     320.0  0.520868  0.193381  0.041322  0.383264  0.549587  0.669421
# pixel_4     320.0  0.558458  0.185826  0.111570  0.456612  0.586777  0.699380
# ...           ...       ...       ...       ...       ...       ...       ...
# pixel_4091  320.0  0.332658  0.184645  0.012397  0.177686  0.301653  0.455579
# pixel_4092  320.0  0.335640  0.193152  0.049587  0.173554  0.301653  0.462810
# pixel_4093  320.0  0.323631  0.188717  0.057851  0.173554  0.293388  0.446281
# pixel_4094  320.0  0.315457  0.181919  0.061983  0.177686  0.278926  0.418388
# pixel_4095  320.0  0.310563  0.179779  0.033058  0.173554  0.270661  0.417355
#
#                  max
# pixel_0     0.805785
# pixel_1     0.822314
# pixel_2     0.871901
# pixel_3     0.855372
# pixel_4     0.863636
# ...              ...
# pixel_4091  0.785124
# pixel_4092  0.921488
# pixel_4093  0.929752
# pixel_4094  0.884298
# pixel_4095  0.822314
#
# [4096 rows x 8 columns]

# %%
df_describe["rango"] = df_describe["max"] - df_describe["min"]
print(df_describe["rango"].describe())
sns.histplot(df_describe["rango"], kde = True)
# Out:
# count    4096.000000
# mean        0.690177
# std         0.097665
# min         0.396694
# 25%         0.636364
# 50%         0.702479
# 75%         0.756198
# max         0.946281
# Name: rango, dtype: float64
# <Axes: xlabel='rango', ylabel='Count'>

# %%
sns.boxplot(df_describe["rango"])
# Out:
# <Axes: ylabel='rango'>

# %%
y_pred = rf_clf_importancia.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      0.50      0.67         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      0.50      0.67         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      0.50      0.67         2
#           16       1.00      1.00      1.00         2
#           17       0.67      1.00      0.80         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      1.00      1.00         2
#           21       1.00      1.00      1.00         2
#           22       0.67      1.00      0.80         2
#           23       0.67      1.00      0.80         2
#           24       1.00      0.50      0.67         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         2
#           29       1.00      1.00      1.00         2
#           30       1.00      1.00      1.00         2
#           31       1.00      1.00      1.00         2
#           32       1.00      1.00      1.00         2
#           33       1.00      1.00      1.00         2
#           34       1.00      1.00      1.00         2
#           35       1.00      1.00      1.00         2
#           36       1.00      1.00      1.00         2
#           37       1.00      1.00      1.00         2
#           38       1.00      1.00      1.00         2
#           39       1.00      1.00      1.00         2
#
#     accuracy                           0.95        80
#    macro avg       0.97      0.95      0.95        80
# weighted avg       0.97      0.95      0.95        80

# %%
# esta es la forma de obetener el recall medio sin copiarlo a ojo

baseline_test = recall_score(y_test, y_pred, average = "macro")
baseline_test
# Out:
# 0.95

# %%
aseline_cv = np.mean(cross_val_score(rf_clf_importancia, X_train, y_train, cv = 5, scoring = "balanced_accuracy"))
aseline_cv
# Out:
# np.float64(0.9349999999999999)

# %% [markdown]
# ### #2 MODELO PARA LAS MICROCÁMARAS
# **Objetivo:** Construir un modelo que pueda funcionar en las microcámaras, es decir que pueda funcionar con datos comprimidos.

# %% [markdown]
# Para cumplir con el objetivo se os ocurre emplear la doble propiedad de la PCA, que permite comprimir datos y mantener la capacidad informativa de estos. Sigue los siguientes pasos:
# 1. Instancia un objeto PCA sobre los datos de Train sin especificar ni componentes ni varianza explicada (o sea sin pasar argumentos).
# 2. Escoge un rango de valores para el número de PCAs que permitan por lo menos una compresión de la imagen de entre el 0.2% y el 2.5% (prueba al menos 5 valores). NOTA: La compresión es la reducción total, es decir una reducción del 1% quiere decir que el dataset se reduce a un 1% de su tamaño original)
# 3. Para el rango anterior entrena un modelo de clasificación y apunta su scoring en una validación cruzada de 5 folds y métrica el recall medio y su scoring contra test.
# 4. Muestra en un dataframe el valor de numero de componentes principales empleado, el scoring en CV, el scoring contra test, el % de compresión, la diferencia con el scoring de CV del modelo base, la diferencia con el scoring en test.
# 5. Escoge el número de componentes que permitirían tener la mayor compresión con una pérdida inferior a 3 puntos porcentuales tanto en CV como en test. Si no hay escoge el que tenga una pérdida inferior a 5 puntos porcentuales.

# %%
X_train.shape
# Out:
# (320, 4096)

# %%
pca = PCA()
pca.fit(X_train)
# Out:
# PCA()

# %%
pca.n_components

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.23813324, 0.36946243, 0.45315516, 0.50389934, 0.54082537,
#        0.5733734 , 0.5975542 , 0.6184816 , 0.63774323, 0.6546737 ,
#        0.6705587 , 0.6852649 , 0.69815856, 0.7102453 , 0.721577  ,
#        0.7311504 , 0.739924  , 0.7484213 , 0.75619745, 0.7636284 ,
#        0.77095926, 0.7773812 , 0.783356  , 0.78905064, 0.79466647,
#        0.8001132 , 0.805301  , 0.81030816, 0.8151073 , 0.81967175,
#        0.8240366 , 0.8280795 , 0.8318868 , 0.83535427, 0.83874553,
#        0.8420229 , 0.8452384 , 0.84839934, 0.8513041 , 0.85416734,
#        0.9916084 , 0.991769  , 0.9919273 , 0.99208415, 0.99223936,
#        0.9923925 , 0.99254376, 0.9926935 , 0.9928422 , 0.99299026,
#        0.9931351 , 0.9932792 , 0.9934211 , 0.99355954, 0.9936968 ,
#        0.99383265, 0.9939676 , 0.9941013 , 0.9942342 , 0.99436444,
#        0.9944917 , 0.99461794, 0.9947432 , 0.9948675 , 0.9949895 ,
#        0.9951105 , 0.99523056, 0.99534905, 0.9954656 , 0.9955806 ,
#        0.9956929 , 0.99580485, 0.99591607, 0.9960252 , 0.9961326 ,
#        0.99623865, 0.99634355, 0.9964476 , 0.99655074, 0.99665266,
#        0.99675393, 0.9968533 , 0.99695194, 0.9970472 , 0.99714184,
#        0.9972341 , 0.9973255 , 0.99741584, 0.997505  , 0.9975931 ,
#        0.9976802 , 0.99776626, 0.9978511 , 0.99793494, 0.9980183 ,
#        0.99809986, 0.99818045, 0.99825835, 0.99833506, 0.9984107 ,
#        0.99848545, 0.99855846, 0.9986311 , 0.99870247, 0.9987707 ,
#        0.9988376 , 0.99890345, 0.998969  , 0.99903405, 0.9990965 ,
#        0.99915755, 0.9992172 , 0.99927586, 0.99933213, 0.99938804,
#        0.99944234, 0.999496  , 0.99954844, 0.9995992 , 0.9996475 ,
#        0.99969476, 0.9997416 , 0.9997871 , 0.99983054, 0.99986905,
#        0.9999066 , 0.99994105, 0.9999745 , 1.0000005 , 1.0000005 ],
#       dtype=float32)

# %%
num_pcs = 0.2 * num_features / 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 num_pcs = 0.2 * num_features / 100
#
# NameError: name 'num_features' is not defined

# %%
X_train.to_csv("prueba.csv")

# %%
X_train.iloc[:,0:8].to_csv("prueba_comprimida.csv")

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.23813324, 0.36946243, 0.45315516, 0.50389934, 0.54082537,
#        0.5733734 , 0.5975542 , 0.6184816 , 0.63774323, 0.6546737 ,
#        0.6705587 , 0.6852649 , 0.69815856, 0.7102453 , 0.721577  ,
#        0.7311504 , 0.739924  , 0.7484213 , 0.75619745, 0.7636284 ,
#        0.77095926, 0.7773812 , 0.783356  , 0.78905064, 0.79466647,
#        0.8001132 , 0.805301  , 0.81030816, 0.8151073 , 0.81967175,
#        0.8240366 , 0.8280795 , 0.8318868 , 0.83535427, 0.83874553,
#        0.8420229 , 0.8452384 , 0.84839934, 0.8513041 , 0.85416734,
#        0.85694057, 0.85961485, 0.86216134, 0.8646439 , 0.86709595,
#        0.8694816 , 0.8718445 , 0.8741369 , 0.87629354, 0.87839854,
#        0.88041353, 0.8823954 , 0.884337  , 0.88623834, 0.8881127 ,
#        0.88991934, 0.8916903 , 0.89343506, 0.89514077, 0.8968169 ,
#        0.89844435, 0.9000513 , 0.90159833, 0.90309125, 0.90457296,
#        0.9059979 , 0.9074134 , 0.90881157, 0.9101936 , 0.9115449 ,
#        0.91288084, 0.9141539 , 0.9154198 , 0.9166415 , 0.91785383,
#        0.91904634, 0.92019814, 0.9213359 , 0.92245567, 0.9235475 ,
#        0.9246307 , 0.92569137, 0.9267286 , 0.92776126, 0.9287785 ,
#        0.99675393, 0.9968533 , 0.99695194, 0.9970472 , 0.99714184,
#        0.9972341 , 0.9973255 , 0.99741584, 0.997505  , 0.9975931 ,
#        0.9976802 , 0.99776626, 0.9978511 , 0.99793494, 0.9980183 ,
#        0.99809986, 0.99818045, 0.99825835, 0.99833506, 0.9984107 ,
#        0.99848545, 0.99855846, 0.9986311 , 0.99870247, 0.9987707 ,
#        0.9988376 , 0.99890345, 0.998969  , 0.99903405, 0.9990965 ,
#        0.99915755, 0.9992172 , 0.99927586, 0.99933213, 0.99938804,
#        0.99944234, 0.999496  , 0.99954844, 0.9995992 , 0.9996475 ,
#        0.99969476, 0.9997416 , 0.9997871 , 0.99983054, 0.99986905,
#        0.9999066 , 0.99994105, 0.9999745 , 1.0000005 , 1.0000005 ],
#       dtype=float32)

# %%
num_pca = 2.5 / 100 * 4096
num_pca
# Out:
# 102.4

# %%
np.linspace(0.2,2.5,5)
# Out:
# array([0.2  , 0.775, 1.35 , 1.925, 2.5  ])

# %%
compresion_maxima = 0.2
compresion_minima = 2.5

num_pcs = []
num_features = len(X_train.columns)  # Si son 4096, por florear un poco

for rango in np.linspace(compresion_maxima, compresion_minima, 10):
    # grado de compresión = num_pca / num_features * 100
    # -> num_pca = grado_compresion * num_features / 100
    num_pc = int(rango * num_features / 100)
    print(f"Para {rango}% de compresión, voy a probar {num_pc} PCs")
    num_pcs.append(num_pc)

print("Rangos que voy a probar:")
print(num_pcs)
# Out:
# Para 0.2% de compresión, voy a probar 8 PCs
# Para 0.45555555555555555% de compresión, voy a probar 18 PCs
# Para 0.711111111111111% de compresión, voy a probar 29 PCs
# Para 0.9666666666666666% de compresión, voy a probar 39 PCs
# Para 1.222222222222222% de compresión, voy a probar 50 PCs
# Para 1.4777777777777776% de compresión, voy a probar 60 PCs
# Para 1.7333333333333332% de compresión, voy a probar 70 PCs
# Para 1.9888888888888887% de compresión, voy a probar 81 PCs
# Para 2.2444444444444445% de compresión, voy a probar 91 PCs
# Para 2.5% de compresión, voy a probar 102 PCs
# Rangos que voy a probar:
# [8, 18, 29, 39, 50, 60, 70, 81, 91, 102]

# %%
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

X_train_pca.shape
# Out:
# (320, 320)

# %%
X_test_pca.shape
# Out:
# (80, 320)

# %%
num_pcs
# Out:
# [8, 18, 29, 39, 50, 60, 70, 81, 91, 102]

# %%
pd.DataFrame(X_train_pca[:,:8])
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.056992  1.711270 -2.704211 -1.373929 -1.453249  0.381898  1.044010
# 1     9.930923 -5.001657  1.482943  1.453294  1.822160 -1.578504  1.418200
# 2     2.818077  3.181491 -1.091955  1.348546 -0.901585 -0.619281  1.358771
# 3     1.718903 -6.751397 -0.149678 -0.282960 -1.075768  1.124096  2.538236
# 4     2.330814  5.347820  1.583536 -2.392990 -2.441764 -0.568963 -1.091206
# ..         ...       ...       ...       ...       ...       ...       ...
# 315   3.272583 -2.657257  0.385544  1.345019 -2.093507  0.213593  2.935342
# 316  -1.594879  2.194950 -1.605914 -3.996032  0.449127  1.649900  0.482944
# 317 -10.048662 -0.153246  0.031918  0.426837 -0.415296 -1.338411  0.052054
# 318   2.648785  1.050327 -2.957838  0.831132 -1.424505  1.058623  1.249935
# 319   5.136982  1.260545  1.904960 -2.792751  1.982227 -1.697319 -2.280839
#
#             7
# 0    2.071063
# 1   -0.047985
# 2   -0.539961
# 3    0.655477
# 4   -1.199133
# ..        ...
# 315 -3.166195
# 316 -3.481728
# 317 -2.254852
# 318 -0.337572
# 319 -1.690210
#
# [320 rows x 8 columns]

# %%
lista_valores = []

rf_clf = RandomForestClassifier(random_state=42)

for num_pc in num_pcs:
    X_train_temp = X_train_pca[:, :num_pc]
    X_test_temp = X_test_pca[:, :num_pc]

    eval_cv = np.mean(cross_val_score(rf_clf, X_train_temp, y_train, cv=5, scoring="balanced_accuracy"))

    rf_clf.fit(X_train_temp, y_train)
    y_pred = rf_clf.predict(X_test_temp)
    eval_test = recall_score(y_test, y_pred, average="macro")

    datos = {
        "num_pc": num_pc,
        "factor compresión": round(num_pc / num_features * 100, 2),
        "eval_cv": eval_cv * 100,
        "baseline_cv": aseline_cv * 100,
        "diff_cv": (aseline_cv - eval_cv) * 100,
        "eval_test": eval_test * 100,
        "baseline_test": baseline_test * 100,
        "diff_test": (baseline_test - eval_test) * 100
    }

    lista_valores.append(datos.copy())

# %%
lista_valores
# Out:
# [{'num_pc': 8,
#   'factor compresión': 0.2,
#   'eval_cv': np.float64(80.5),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(13.0),
#   'eval_test': 76.25,
#   'baseline_test': 95.0,
#   'diff_test': 18.75},
#  {'num_pc': 18,
#   'factor compresión': 0.44,
#   'eval_cv': np.float64(90.75),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(2.749999999999997),
#   'eval_test': 88.75,
#   'baseline_test': 95.0,
#   'diff_test': 6.25},
#  {'num_pc': 29,
#   'factor compresión': 0.71,
#   'eval_cv': np.float64(90.5),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(2.9999999999999916),
#   'eval_test': 90.0,
#   'baseline_test': 95.0,
#   'diff_test': 4.999999999999993},
#  {'num_pc': 39,
#   'factor compresión': 0.95,
#   'eval_cv': np.float64(90.25000000000001),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(3.2499999999999862),
#   'eval_test': 93.75,
#   'baseline_test': 95.0,
#   'diff_test': 1.2499999999999956},
#  {'num_pc': 50,
#   'factor compresión': 1.22,
#   'eval_cv': np.float64(90.99999999999999),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(2.500000000000002),
#   'eval_test': 91.25,
#   'baseline_test': 95.0,
#   'diff_test': 3.749999999999998},
#  {'num_pc': 60,
#   'factor compresión': 1.46,
#   'eval_cv': np.float64(93.0),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(0.49999999999998934),
#   'eval_test': 90.0,
#   'baseline_test': 95.0,
#   'diff_test': 4.999999999999993},
#  {'num_pc': 70,
#   'factor compresión': 1.71,
#   'eval_cv': np.float64(90.49999999999999),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(3.0000000000000027),
#   'eval_test': 92.5,
#   'baseline_test': 95.0,
#   'diff_test': 2.499999999999991},
#  {'num_pc': 81,
#   'factor compresión': 1.98,
#   'eval_cv': np.float64(91.75000000000001),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(1.749999999999985),
#   'eval_test': 93.75,
#   'baseline_test': 95.0,
#   'diff_test': 1.2499999999999956},
#  {'num_pc': 91,
#   'factor compresión': 2.22,
#   'eval_cv': np.float64(91.25),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(2.2499999999999964),
#   'eval_test': 92.5,
#   'baseline_test': 95.0,
#   'diff_test': 2.499999999999991},
#  {'num_pc': 102,
#   'factor compresión': 2.49,
#   'eval_cv': np.float64(89.49999999999999),
#   'baseline_cv': np.float64(93.5),
#   'diff_cv': np.float64(4.0000000000000036),
#   'eval_test': 95.0,
#   'baseline_test': 95.0,
#   'diff_test': 0.0}]

# %%
df_resultados = pd.DataFrame(lista_valores)
df_resultados
# Out:
#    num_pc  factor compresión  eval_cv  baseline_cv  diff_cv  eval_test  \
# 0       8               0.20    80.50         93.5    13.00      76.25
# 1      18               0.44    90.75         93.5     2.75      88.75
# 2      29               0.71    90.50         93.5     3.00      90.00
# 3      39               0.95    90.25         93.5     3.25      93.75
# 4      50               1.22    91.00         93.5     2.50      91.25
# 5      60               1.46    93.00         93.5     0.50      90.00
# 6      70               1.71    90.50         93.5     3.00      92.50
# 7      81               1.98    91.75         93.5     1.75      93.75
# 8      91               2.22    91.25         93.5     2.25      92.50
# 9     102               2.49    89.50         93.5     4.00      95.00
#
#    baseline_test  diff_test
# 0           95.0      18.75
# 1           95.0       6.25
# 2           95.0       5.00
# 3           95.0       1.25
# 4           95.0       3.75
# 5           95.0       5.00
# 6           95.0       2.50
# 7           95.0       1.25
# 8           95.0       2.50
# 9           95.0       0.00

# %%
plt.figure(figsize=(8,8))
umbral_corte_1 = 3.25
umbral_corte_2 = 5

for lineas in ["diff_cv", "diff_test"]:
    plt.plot(df_resultados["factor compresión"], df_resultados[lineas], label=lineas)

plt.xlabel("Factor Compresión")
plt.ylabel("Diff con baseline")

plt.axhline(y=umbral_corte_1, color='r', linestyle='-', label=f"Umbral {umbral_corte_1} pp")
plt.axhline(y=umbral_corte_2, color='b', linestyle='--', label=f"Umbral {umbral_corte_2} pp")

plt.legend()

# %%
cumple_umbral_1 = (df_resultados["diff_cv"] <= umbral_corte_1) & (df_resultados["diff_test"] <= umbral_corte_1)
df_resultados[cumple_umbral_1]
# Out:
#    num_pc  factor compresión  eval_cv  baseline_cv  diff_cv  eval_test  \
# 3      39               0.95    90.25         93.5     3.25      93.75
# 6      70               1.71    90.50         93.5     3.00      92.50
# 7      81               1.98    91.75         93.5     1.75      93.75
# 8      91               2.22    91.25         93.5     2.25      92.50
#
#    baseline_test  diff_test
# 3           95.0       1.25
# 6           95.0       2.50
# 7           95.0       1.25
# 8           95.0       2.50

# %% [markdown]
# ### #3 COMPRESION PARA CLASIFICACION POSTERIOR

# %% [markdown]
# **Objetivo**: Obtener el número de componentes que permita una compresión menor y al tiempo que el modelo en el servidor central no baje su rendimiento respecto a no usar imágenes comprimidas.

# %% [markdown]
# Para esta parte la idea que se os ha ocurrido es emplear también la PCA como compresor ya que así siempre podrían pasar a la opción anterior si eso fuese suficiente. Pero en este caso no vamos a utilizar el dataset comprimido con las PCAs para detectar las caras, sino el dataset una vez descomprimido (recuerda que puede emplear `inverse_transform` para "descomprimir"). Los pasos a seguir son:
#
# 1. Escoge un rango de valores que  permitan una compresión aún mayor (recuerda que el ancho de banda es mínimo) entre el 1 por mil y el 1 por ciento. Escoge 5 valores de número de PCAs que permitan movernos en ese rango.
# 2. Para cada uno de esos valores: aplica la PCA al X_train, obten un X_train_unzipped aplicando la inversa de la PCA y entrena un modelo de clasificación y pruébalo contra test, apunta el balanced accuracy.
# 3. Crea un dataframe o haz un visualización comparando como es la medidad de balance accuracy para cada valor de número de pcas escogido y cuál su factor de compresión.
# 4. Sabiendo que no podemos perder más de 3 puntos porcentuales respecto al baseline, ¿qué numero de PCA escogerías?

# %%
compresion_maxima = 0.1
compresion_minima = 1

num_pcas = []
num_features = len(X_train.columns)  # Si son 4096, por florear un poco

for rango in np.linspace(compresion_maxima, compresion_minima, 10):
    # grado compresion = num_pca/num_features * 100 -> num_pca = grado_compresion * num_features / 100
    num_pca = int(rango * num_features / 100)
    num_pcas.append(num_pca)

print("Rangos que voy a probar:")
print(num_pcas)
# Out:
# Rangos que voy a probar:
# [4, 8, 12, 16, 20, 24, 28, 32, 36, 40]

# %%
lista_valores = []

rf_clf = RandomForestClassifier(random_state=42)

for num_pca in num_pcas:
    pca_temp = PCA(num_pca)  # Por una cuestión de funcionamiento de la clase PCA tenemos que "comprimir" de nuevo
    X = pca_temp.fit_transform(X_train)
    X_t = pca_temp.transform(X_test)

    X_train_temp = pca_temp.inverse_transform(X)  # AQUI ESTA LA CLAVE, primero nos quedamos con el dataset pequeño
    print("num pcas:", num_pca, "num features descomprimidas:", X_train_temp.shape[1])

    X_test_temp = pca_temp.inverse_transform(X_t)  # APLICAMOS lo mismo a test

    eval_cv = np.mean(cross_val_score(rf_clf, X_train_temp, y_train, cv=5, scoring="balanced_accuracy"))

    rf_clf.fit(X_train_temp, y_train)
    y_pred = rf_clf.predict(X_test_temp)
    eval_test = recall_score(y_test, y_pred, average="macro")

    datos = {
        "num_pca": num_pca,
        "factor compresión": round(num_pca / num_features * 100, 2),
        "eval_cv": eval_cv * 100,
        "baseline_cv": aseline_cv * 100,
        "diff_cv": (aseline_cv - eval_cv) * 100,
        "eval_test": eval_test * 100,
        "baseline_test": baseline_test * 100,
        "diff_test": (baseline_test - eval_test) * 100
    }

    lista_valores.append(datos.copy())
# Out:
# num pcas: 4 num features descomprimidas: 4096
# num pcas: 8 num features descomprimidas: 4096
# num pcas: 12 num features descomprimidas: 4096
# num pcas: 16 num features descomprimidas: 4096
# num pcas: 20 num features descomprimidas: 4096
# num pcas: 24 num features descomprimidas: 4096
# num pcas: 28 num features descomprimidas: 4096
# num pcas: 32 num features descomprimidas: 4096
# num pcas: 36 num features descomprimidas: 4096
# num pcas: 40 num features descomprimidas: 4096

# %%
df_resultados = pd.DataFrame(lista_valores)
df_resultados
# Out:
#    num_pca  factor compresión  eval_cv  baseline_cv  diff_cv  eval_test  \
# 0        4               0.10    61.75         93.5    31.75      57.50
# 1        8               0.20    77.25         93.5    16.25      75.00
# 2       12               0.29    82.50         93.5    11.00      85.00
# 3       16               0.39    87.75         93.5     5.75      87.50
# 4       20               0.49    91.75         93.5     1.75      88.75
# 5       24               0.59    91.00         93.5     2.50      90.00
# 6       28               0.68    91.25         93.5     2.25      92.50
# 7       32               0.78    91.00         93.5     2.50      96.25
# 8       36               0.88    90.50         93.5     3.00      90.00
# 9       40               0.98    91.50         93.5     2.00      95.00
#
#    baseline_test  diff_test
# 0           95.0      37.50
# 1           95.0      20.00
# 2           95.0      10.00
# 3           95.0       7.50
# 4           95.0       6.25
# 5           95.0       5.00
# 6           95.0       2.50
# 7           95.0      -1.25
# 8           95.0       5.00
# 9           95.0       0.00

# %%
plt.figure(figsize=(8,8))

umbral_corte_1 = 3
umbral_corte_2 = 5

for lineas in ["diff_cv","diff_test"]:
    plt.plot(df_resultados["factor compresión"], df_resultados[lineas], label = lineas)

plt.xlabel("Factor Compresión")
plt.ylabel("Diff con baseline")

plt.axhline(y = umbral_corte_1, color = 'r', linestyle = '-.', label = f"Umbral {umbral_corte_1} pp")
plt.axhline(y = umbral_corte_2, color = "b", linestyle = "--", label = f"Umbral {umbral_corte_2} pp")

plt.legend()

# %%
cumple_umbral_1 = (df_resultados["diff_cv"] <= umbral_corte_1) & (df_resultados["diff_test"] <= umbral_corte_1)
df_resultados[cumple_umbral_1]
# Out:
#    num_pca  factor compresión  eval_cv  baseline_cv  diff_cv  eval_test  \
# 6       28               0.68    91.25         93.5     2.25      92.50
# 7       32               0.78    91.00         93.5     2.50      96.25
# 9       40               0.98    91.50         93.5     2.00      95.00
#
#    baseline_test  diff_test
# 6           95.0       2.50
# 7           95.0      -1.25
# 9           95.0       0.00

# %% [markdown]
# ### #EXTRA

# %%
def pinta_caras(faces, title=""):
    faces = faces.reshape(-1, 64, 64)
    n_cols = 10
    n_rows = (len(faces) - 1) // n_cols + 1
    plt.figure(figsize=(n_cols * 4, n_rows * 4.4))
    for index, face in enumerate(faces):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(face, cmap="gray")
        plt.axis("off")
    plt.title(title)
    plt.show()

# %%
for num_pca in num_pcas + [150,300]:  # Añadimos 2 más para que se vea que son las mismas caras :-D
    pca_temp = PCA(num_pca)  # Por una cuestión de funcionamiento de la clase PCA tenemos que "comprimir" de nuevo
    X = pca_temp.fit_transform(X_train)
    X_train_temp = pca_temp.inverse_transform(X)  # AQUI ESTA LA CLAVE, primero nos quedamos con el dataset pequeño
    
    pinta_caras(X_train_temp[:5], title="Sin comprimir")
    pinta_caras(X_train_temp[:5], title=f"{round(num_pca/num_features*100,2)}% de compresión ({num_pca} PCs)")

# %% [markdown]
# 1. Para la segunda parte, visualiza en cuatro gráficos un scatter plot de las dos primeras componentes principales de la PCA escogida y colorea cada punto con las clases correspondientes a cada cara (como hay 40 clases, usa 10 por gráfico, 1-10 en el primero, 11-20 en el segundo, etc)
# 2. Para la tercer parte crea una función (modifica la de la práctica de la unidad de KMeans, por ejemplo) que permita ver la cara sin comprimir y la cara después de haberla descomprimido y haz una comprobación de cómo quedan (visualiza 5 caras por ejemplo) para cada uno de los valores de números de PCAs probados. Añade el caso para 150 y 300 PCs para que se vea que son las mismas claras con claridad.
